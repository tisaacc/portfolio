# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib 
import matplotlib.pyplot as plt
plt.style.use('tableau-colorblind10')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
# Reading in the data

df = pd.read_csv('/Users/isaaccassedy/Downloads/movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Checking for missing values

df.isna().sum()/(len(df))*100
# Out:
# name         0.000000
# rating       1.004173
# genre        0.000000
# year         0.000000
# released     0.026082
# score        0.039124
# votes        0.039124
# director     0.000000
# writer       0.039124
# star         0.013041
# country      0.039124
# budget      28.312467
# gross        2.464789
# company      0.221701
# runtime      0.052165
# dtype: float64

# %%
# Dropping missing values

df.dropna(inplace=True)

# %%
df.isna().sum()/(len(df))*100
# Out:
# name        0.0
# rating      0.0
# genre       0.0
# year        0.0
# released    0.0
# score       0.0
# votes       0.0
# director    0.0
# writer      0.0
# star        0.0
# country     0.0
# budget      0.0
# gross       0.0
# company     0.0
# runtime     0.0
# dtype: float64

# %%
# Determining data types

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Removing unnecessary floats

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# The year col states the year in which the film was released and the released column states the exact date of release
# The year values in each should be identical, but they are not. Below I will fix this

df['yearcorrect'] = df['released'].str.extract('([0-9]{4})').astype(int)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Ordering dataframe by gross revenue

df = df.sort_values(by=['gross'], inplace=False, ascending=False).reset_index(drop=True)

# %%
# Checking and dropping any duplicates

df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Scatterplot budget vs. gross revenue

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs. Gross Revenue')
plt.xlabel('Budget')
plt.ylabel('Gross Revenue')
# Out:
# Text(0, 0.5, 'Gross Revenue')

# %%
df.head()
# Out:
#                                          name rating   genre  year  \
# 0                                      Avatar  PG-13  Action  2009
# 1                           Avengers: Endgame  PG-13  Action  2019
# 2                                     Titanic  PG-13   Drama  1997
# 3  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 4                      Avengers: Infinity War  PG-13  Action  2018
#
#                             released  score      votes       director  \
# 0  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 1     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 2  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 3  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 4     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                writer               star        country     budget  \
# 0       James Cameron    Sam Worthington  United States  237000000
# ...

# %%
# Seaborn plot of Budget vs. Gross

sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'blue'}, line_kws={'color':'orange'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Numeric correlations

corr = df.corr()

sns.heatmap(corr, annot=True)
plt.title('Numeric Correlations')
plt.xlabel('Film Characteristics')
plt.ylabel('Film Characteristics')
# Out:
# Text(87.0, 0.5, 'Film Characteristics')

# %%
# Correlations for string cols

df_categorized = df.copy()

for col in df_categorized.columns:
    if df_categorized[col].dtype == 'object':
        df_categorized[col] = df_categorized[col].astype('category')
        df_categorized[col] = df_categorized[col].cat.codes

df_categorized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0      386       5      0  2009       527    7.8  1100000.0       785    1263
# 1      388       5      0  2019       137    8.4   903000.0       105     513
# 2     4909       5      6  1997       534    7.8  1100000.0       785    1263
# 3     3643       5      0  2015       529    7.8   876000.0       768    1806
# 4      389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5416  3794       6      6  2009       890    5.8     3500.0       585    2924
# 5417  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 5418  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 5419  2909       6      9  1982      1525    3.9     2300.0       261      55
# 5420  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
corr_cat = df_categorized.corr()

sns.heatmap(corr_cat, annot=True)
plt.title('Total Correlations')
plt.xlabel('Film Characteristics')
plt.ylabel('Film Characteristics')
# Out:
# Text(87.0, 0.5, 'Film Characteristics')

# %%
pd.set_option('display.max_rows', None)
correlation_matrix = df_categorized.corr()
corr_pairs = correlation_matrix.unstack()
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs
# Out:
# yearcorrect  yearcorrect    1.000000
# runtime      runtime        1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# votes        votes          1.000000
# director     director       1.000000
# writer       writer         1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# company      company        1.000000
# name         name           1.000000
# yearcorrect  year           0.998726
# year         yearcorrect    0.998726
# budget       gross          0.740247
# gross        budget         0.740247
# votes        gross          0.614751
# gross        votes          0.614751
# votes        score          0.474256
# score        votes          0.474256
# budget       votes          0.439675
# ...

# %%
high_corr = sorted_pairs[sorted_pairs > 0.5]
high_corr
# Out:
# yearcorrect  yearcorrect    1.000000
# runtime      runtime        1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# votes        votes          1.000000
# director     director       1.000000
# writer       writer         1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# company      company        1.000000
# name         name           1.000000
# yearcorrect  year           0.998726
# year         yearcorrect    0.998726
# budget       gross          0.740247
# gross        budget         0.740247
# votes        gross          0.614751
# gross        votes          0.614751
# dtype: float64

# %% [markdown]
# ### Through calculating these correlations and visualizing them, it is evident that the highest correlations are between budget and gross, and votes and gross
